# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
tips = sns.load_dataset("tips")

# Create a histogram of total bills
sns.histplot(data=tips, x="total_bill", kde=True, color="skyblue")
plt.title("Distribution of Total Bills")
plt.show()

# %%
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=["o", "x"])
plt.title("Regression Line of Tip vs Total Bill by Gender")
plt.show()

# %%
iris = sns.load_dataset("iris")
corr = iris.select_dtypes(include='number').corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Iris Features")
plt.show()

# %%
sns.pairplot(iris, hue="species", palette="husl")
plt.suptitle("Pairwise Feature Relationships in Iris Dataset", y=1.02)
plt.show()

# %%
g = sns.FacetGrid(tips, col="sex", row="time")
g.map(sns.histplot, "total_bill", color="orange")
g.add_legend()
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips, palette="magma")
plt.title("Average Total Bill per Day by Gender")
plt.show()
